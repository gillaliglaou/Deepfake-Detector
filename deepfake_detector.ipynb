# %% [markdown]
# ##imports

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import  concatenate
from tensorflow import keras
import tensorflow as tf
import pandas as pd
from PIL import Image
import numpy as np

# %% [markdown]
# ##model

# %%
class PyramidPoolingModule(tf.keras.layers.Layer):
    def __init__(self, num_filters=1, kernel_size=(1, 1), bin_sizes=[1, 2, 3, 6], pool_mode='avg', **kwargs):
        super(PyramidPoolingModule, self).__init__(**kwargs)
        self.num_filters = num_filters
        self.kernel_size = kernel_size
        self.bin_sizes = bin_sizes
        self.pool_mode = pool_mode
        self.pyramid_pooling = self.build_pyramid_pooling()

    def build_pyramid_pooling(self):
        return PyramidPoolingModule.PyramidPoolingModule(
            num_filters=self.num_filters,
            kernel_size=self.kernel_size,
            bin_sizes=self.bin_sizes,
            pool_mode=self.pool_mode,
        )

    def call(self, inputs):
        return self.pyramid_pooling(inputs)

    class PyramidPoolingModule(tf.keras.layers.Layer):
        def __init__(self, num_filters, kernel_size, bin_sizes, pool_mode, **kwargs):
            super(PyramidPoolingModule.PyramidPoolingModule, self).__init__(**kwargs)
            self.num_filters = num_filters
            self.kernel_size = kernel_size
            self.bin_sizes = bin_sizes
            self.pool_mode = pool_mode
            self.pyramid_layers = []

            for bin_size in bin_sizes:
                self.pyramid_layers.append(
                    layers.Conv2D(
                        filters=num_filters,
                        kernel_size=kernel_size,
                        padding='same',
                        activation='relu'
                    )
                )

        def call(self, inputs):
            outputs = [inputs]

            for i, bin_size in enumerate(self.bin_sizes):
                pooled = tf.keras.layers.AveragePooling2D(pool_size=(bin_size, bin_size))(inputs)
                convolved = self.pyramid_layers[i](pooled)
                resized = tf.image.resize(convolved, tf.shape(inputs)[1:3])
                outputs.append(resized)

            return tf.concat(outputs, axis=-1)
def conv3x3(in_planes, out_planes, stride=1, has_bias=False):
    """
    3x3 convolution with padding
    """
    return tf.keras.layers.Conv2D(
        filters=out_planes,
        kernel_size=(3, 3),
        strides=stride,
        padding='same',
        use_bias=has_bias,
        activation=None
    )

def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

class BayarConv2d(tf.keras.layers.Layer):
    def __init__(self, in_channels, out_channels, kernel_size=5, stride=1, padding=0):
        super(BayarConv2d, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.stride = stride
        self.padding = padding
        self.minus1 = tf.ones((self.in_channels, self.out_channels, 1)) * -1.000

        self.kernel = self.add_weight(shape=(self.in_channels, self.out_channels, kernel_size ** 2 - 1),
                                      initializer='random_normal',
                                      trainable=True)

    def bayarConstraint(self):
        kernel_permuted = tf.transpose(self.kernel, perm=[2, 0, 1])
        kernel_sum = tf.reduce_sum(kernel_permuted, axis=0)
        ctr = self.kernel_size ** 2 // 2
        real_kernel = tf.concat([self.kernel[:, :, :ctr], self.minus1, self.kernel[:, :, ctr:]], axis=2)
        real_kernel = tf.reshape(real_kernel, (self.out_channels, self.in_channels, self.kernel_size, self.kernel_size))
        return real_kernel

    def call(self, x):
        x = tf.nn.conv2d(x, self.bayarConstraint(), strides=self.stride, padding='SAME')
        return x

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_encoder(input_shape=(256, 256, 3)):
    inputs = Input(input_shape)

    resnet50 = ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)

    s1 = resnet50.layers[0].output         ## (512 x 512)
    s2 = resnet50.get_layer("conv1_relu").output        ## (256 x 256)
    s3 = resnet50.get_layer("conv2_block3_out").output  ## (128 x 128)
    s4 = resnet50.get_layer("conv3_block4_out").output  ## (64 x 64)
    b1 = resnet50.get_layer("conv4_block6_out").output
    encoder_model = Model(inputs=inputs, outputs=[s1, s2, s3, s4,b1])
    encoder_model.trainable = False

    return encoder_model

def assemblage(input_shape=(256, 256, 3)):
    in_channels= 3
    out_channels = 3
    kernel_size = 3
    stride = 1
    padding = 0
    bayar_conv = BayarConv2d(in_channels, out_channels, kernel_size, stride, padding)
    inputs = Input(input_shape)
    x=bayar_conv(inputs)
    encoder_model = build_encoder(input_shape)
    encoder_layers=encoder_model(inputs)
    encoder_layers_bayer=encoder_model(x)
    num_layers = len(encoder_layers)
    concatenated_layers_list = []
    for layer,layer_bayar in zip(encoder_layers, encoder_layers_bayer):
        concatenated_layers=concatenate([layer,layer_bayar], axis=-1)
        output = conv3x3(in_planes=concatenated_layers.shape[-1], out_planes=layer.shape[-1])(concatenated_layers)
        concatenated_layers_list.append(output)
    s1,s2,s3,s4,b1=concatenated_layers_list
    ppm_output = PyramidPoolingModule()(b1)
    """ Decoder """
    d1 = decoder_block(ppm_output, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    """ Output """

    """ Localization """
    localization_output = Conv2D(1, 1, padding="same", activation="sigmoid",name="localization_output")(d4)

    """ Classification """
    avg_pooled = keras.layers.GlobalAveragePooling2D()(ppm_output)
    classification_output = keras.layers.Dense(
        1, activation="sigmoid", name="classification_output"
    )(avg_pooled)
    model = Model(inputs, outputs=[localization_output,classification_output], name="ResNet50_U-Net")
    return model

# %%
model=assemblage()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %% [markdown]
# ##data

# %%
# !kaggle datasets download -d mohamedbenticha/tsyp-cs-challenge
! unzip "tsyp-cs-challenge.zip"
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0023_cha0026_0510_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0024_ani0058_0417_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0025_cha0024_0511_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0026_art0095_0467_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0028_ani0068_0421_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0029_art0068_0463_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0032_ani0079_0512_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0036_art0090_0465_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0037_ani0061_0419_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0037_cha0043_0513_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0041_cha0038_0514_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0044_ani0009_0407_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0048_cha0049_0496_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0051_art0014_0459_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0054_cha0040_0494_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0055_ani0079_0425_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0056_ani0005_0406_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0057_ani0021_0410_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0062_cha0063_0515_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0063_art0029_0461_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0066_ani0040_0516_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0068_cha0067_0517_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0069_art0081_0518_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0069_cha0080_0179_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0070_cha0075_0500_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0070_cha0075_0519_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0071_art0027_0460_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0074_cha0083_0520_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0078_cha0099_0521_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0084_cha0044_0522_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0087_cha0098_0523_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0088_cha0028_0524_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0094_cha0089_0503_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0095_ani0078_0424_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_cha0095_cha0086_0525_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat0001_cha0053_0497_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat0002_cha0009_0486_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat0018_nat0016_0180_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat0023_art0060_0526_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat0028_ani0070_0423_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat0028_sec0029_0527_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat0030_nat0028_0528_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat0032_nat0040_0529_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat0033_cha0074_0499_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat0035_nat0033_0530_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat0038_ani0005_0531_gt.png
#   inflating: TSYP/final data/SHALLOWFAKE/Casia1.0/CASIA 1.0 groundtruth/Sp/Sp_D_NRN_A_nat
png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_8333.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_8439.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_8545.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_8582.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_8653.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_8665.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_8733.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_8780.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_8860.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_8910.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_8970.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9016.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9028.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9037.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9072.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9094.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9097.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9117.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9183.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9249.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9383.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9387.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9444.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9485.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9503.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9508.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9558.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9569.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9587.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9654.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9671.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9704.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9768.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9831.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9836.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9852.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9855.png
#   inflating: TSYP/final data/SHALLOWFAKE/NIST2016/NC2016_Test0613/reference/splice/mask/NC2016_9925.png
#   inflating: TSYP/mask.png
#   inflating: TSYP/train.csv
#   inflating: TSYP/val.csv
#   inflating: test.csv

# %%
class ValDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, data, batch_size=8, shuffle=True):
        self.data = data
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.data) / self.batch_size))

    def __getitem__(self, index):
        batch_data = self.data[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []
        labels = []

        for _, row in batch_data.iterrows():
            image = load_img(row['image'], target_size=(256, 256))
            image = img_to_array(image) / 255.0
            images.append(image)

            mask = load_img(row['mask'], target_size=(256, 256), color_mode='grayscale')
            mask = img_to_array(mask) / 255.0
            masks.append(mask)

            labels.append(row['class'])

        images = np.array(images)
        masks = np.array(masks)
        labels = np.array(labels)

        return images, [masks, labels]

    def on_epoch_end(self):
        if self.shuffle:
            self.data = self.data.sample(frac=1)
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array

class TrainDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, data, batch_size=32, shuffle=True, augment=True):
        self.data = data
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.augment = augment
        self.on_epoch_end()
        self.Image_gen = tf.keras.preprocessing.image.ImageDataGenerator(
            brightness_range=[0.2, 1.8]
        )

        if self.augment:
            self.image_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
                rotation_range=45,
                zoom_range=0.2,
                horizontal_flip=True,
                fill_mode='nearest',
            )

    def __len__(self):
        return int(np.ceil(len(self.data) / self.batch_size))

    def __getitem__(self, index):
        batch_data = self.data[index * self.batch_size: (index + 1) * self.batch_size]

        images = []
        masks = []
        labels = []

        for _, row in batch_data.iterrows():
            image = load_img(row['image'], target_size=(256, 256))
            image = img_to_array(image)
            image = self.Image_gen.random_transform(image)
            image/=255.0


            mask = load_img(row['mask'], target_size=(256, 256))
            mask = img_to_array(mask) / 255.0

            if self.augment:
                augmented = self.image_datagen.random_transform(np.concatenate([image, mask], axis=-1))
                image, mask = np.split(augmented, 2, axis=-1)
                mask=tf.image.rgb_to_grayscale(mask)

            images.append(image)
            masks.append(mask)
            labels.append(row['class'])

        images = np.array(images)
        masks = np.array(masks)
        labels = np.array(labels)

        return images, [masks, labels]

    def on_epoch_end(self):
        if self.shuffle:
            self.data = self.data.sample(frac=1)

# %%
import pandas as pd
sf_train = pd.read_csv("/content/TSYP/train.csv", na_values="None")
sf_train["image"] = "/content/TSYP/" + sf_train["image"]
sf_train["mask"] = "/content/TSYP/" + sf_train["mask"]
sf_train.fillna("/content/TSYP/mask.png", inplace=True)
sf_val = pd.read_csv("/content/TSYP/val.csv", na_values="None")
sf_val["image"] = "/content/TSYP/" + sf_val["image"]
sf_val["mask"] = "/content/TSYP/" + sf_val["mask"]
sf_val.fillna("/content/TSYP/mask.png", inplace=True)
sf_train = sf_train.sample(frac=1).reset_index(drop=True)
sf_val = sf_val.sample(frac=1).reset_index(drop=True)
sf_val = sf_val.drop(sf_val.index[:9949])
sf_train_generator = TrainDataGenerator(sf_train)
sf_val_gen = ValDataGenerator(sf_val)

# %% [markdown]
# ##compiling

# %%
smooth=1
from keras import backend as K

def dice_coef(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred)
    return (2.0 * intersection + smooth) / (union + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
checkpoint = ModelCheckpoint("/content/drive/My Drive/P2M/best-model.h5", save_best_only=True, monitor="val_loss", mode="min", verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_delta=0.0001, mode='auto', verbose=1)

# %%
adam_optimizer = tf.keras.optimizers.Adam(beta_1=0.9, beta_2=0.999)

# %%
model.compile(optimizer=adam_optimizer, loss=[dice_coef_loss, 'binary_crossentropy'], loss_weights=[0.16, 0.04])

# %%
model.summary()
# Out:
# Model: "ResNet50_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  bayar_conv2d (BayarConv2d)  (None, 256, 256, 3)          72        ['input_1[0][0]']
#
#  model (Functional)          [(None, 256, 256, 3),        8589184   ['input_1[0][0]',
#                               (None, 128, 128, 64),                  'bayar_conv2d[0][0]']
#                               (None, 64, 64, 256),
#                               (None, 32, 32, 512),
#                               (None, 16, 16, 1024)]
#
#  concatenate_4 (Concatenate  (None, 16, 16, 2048)         0         ['model[0][4]',
#  )                                                                   'model[1][4]']
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 1024)         1887436   ['concatenate_4[0][0]']
#                                                           8
#
#  pyramid_pooling_module (Py  (None, 16, 16, 1028)         4100      ['conv2d_4[0][0]']
#  ramidPoolingModule)
#
#  concatenate_3 (Concatenate  (None, 32, 32, 1024)         0         ['model[0][3]',
#  )                                                                   'model[1][3]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 256)          1052928   ['pyramid_pooling_module[0][0]
#  anspose)                                                           ']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 512)          4718592   ['concatenate_3[0][0]']
#
#  concatenate_5 (Concatenate  (None, 32, 32, 768)          0         ['conv2d_transpose[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 256)          1769728   ['concatenate_5[0][0]']
#
#  batch_normalization (Batch  (None, 32, 32, 256)          1024      ['conv2d_9[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 256)          0         ['batch_normalization[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 256)          590080    ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 256)          1024      ['conv2d_10[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  concatenate_2 (Concatenate  (None, 64, 64, 512)          0         ['model[0][2]',
#  )                                                                   'model[1][2]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 128)          131200    ['activation_1[0][0]']
#  Transpose)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 256)          1179648   ['concatenate_2[0][0]']
#
#  concatenate_6 (Concatenate  (None, 64, 64, 384)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_2[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 64, 64, 128)          442496    ['concatenate_6[0][0]']
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['conv2d_11[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 128)          147584    ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64, 64, 128)          512       ['conv2d_12[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  concatenate_1 (Concatenate  (None, 128, 128, 128)        0         ['model[0][1]',
#  )                                                                   'model[1][1]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 64)         32832     ['activation_3[0][0]']
#  Transpose)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)         73728     ['concatenate_1[0][0]']
#
#  concatenate_7 (Concatenate  (None, 128, 128, 128)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 64)         73792     ['concatenate_7[0][0]']
#
#  batch_normalization_4 (Bat  (None, 128, 128, 64)         256       ['conv2d_13[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 64)         36928     ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 128, 128, 64)         256       ['conv2d_14[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 256, 256, 6)          0         ['model[0][0]',
#                                                                      'model[1][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 32)         8224      ['activation_5[0][0]']
#  Transpose)
#
#  conv2d (Conv2D)             (None, 256, 256, 3)          162       ['concatenate[0][0]']
#
#  concatenate_8 (Concatenate  (None, 256, 256, 35)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 32)         10112     ['concatenate_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 256, 256, 32)         128       ['conv2d_15[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_16 (Conv2D)          (None, 256, 256, 32)         9248      ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 256, 256, 32)         128       ['conv2d_16[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  global_average_pooling2d (  (None, 1028)                 0         ['pyramid_pooling_module[0][0]
#  GlobalAveragePooling2D)                                            ']
#
#  localization_output (Conv2  (None, 256, 256, 1)          33        ['activation_7[0][0]']
#  D)
#
#  classification_output (Den  (None, 1)                    1029      ['global_average_pooling2d[0][
#  se)                                                                0]']
#
# ==================================================================================================
# Total params: 37749908 (144.00 MB)
# Trainable params: 29158804 (111.23 MB)
# Non-trainable params: 8591104 (32.77 MB)
# __________________________________________________________________________________________________

# %%
history = model.fit(sf_train_generator, epochs=10, validation_data=sf_val_gen, callbacks=[checkpoint, reduce_lr])
# Out:
# Epoch 1/10
# 584/584 [==============================] - ETA: 0s - loss: 0.2923 - localization_output_loss: 0.7564 - classification_output_loss: 4.2823
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,localization_output_loss,classification_output_loss,lr
# 584/584 [==============================] - 1724s 3s/step - loss: 0.2923 - localization_output_loss: 0.7564 - classification_output_loss: 4.2823 - lr: 0.0010
# Epoch 2/10
# 584/584 [==============================] - ETA: 0s - loss: 0.1359 - localization_output_loss: 0.6787 - classification_output_loss: 0.6822
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,localization_output_loss,classification_output_loss,lr
# 584/584 [==============================] - 1631s 3s/step - loss: 0.1359 - localization_output_loss: 0.6787 - classification_output_loss: 0.6822 - lr: 0.0010
# Epoch 3/10
# 584/584 [==============================] - ETA: 0s - loss: 0.1336 - localization_output_loss: 0.6595 - classification_output_loss: 0.7034
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,localization_output_loss,classification_output_loss,lr
# 584/584 [==============================] - 1640s 3s/step - loss: 0.1336 - localization_output_loss: 0.6595 - classification_output_loss: 0.7034 - lr: 0.0010
# Epoch 4/10
# 584/584 [==============================] - ETA: 0s - loss: 0.1330 - localization_output_loss: 0.6552 - classification_output_loss: 0.7038
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,localization_output_loss,classification_output_loss,lr
# 584/584 [==============================] - 1633s 3s/step - loss: 0.1330 - localization_output_loss: 0.6552 - classification_output_loss: 0.7038 - lr: 0.0010
# Epoch 5/10
# 204/584 [=========>....................] - ETA: 17:34 - loss: 0.1333 - localization_output_loss: 0.6641 - classification_output_loss: 0.6756
